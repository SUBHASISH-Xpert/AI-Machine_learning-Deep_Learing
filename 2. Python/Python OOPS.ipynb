# %% [markdown]
# # OOPS CONCEPT IN PYTHON

# %% [markdown]
# # create object and class

# %%
class student:
    name = "subhasish"
s1 = student()
print(s1.name)
# Out:
# subhasish

# %%
s2 = student()
print(s2.name)
# Out:
# subhasish

# %%
class car:
    color="blue"
    brand ="toyota"

car1 =car()
print(car1.color)
# Out:
# blue

# %%
car1.brand
# Out:
# 'toyota'

# %% [markdown]
# # Constructor

# %%
class employee:
    name = "mohit"
    def __init__(self):
        # it automatically calling
        print("adding new database ...")
s2 = employee()
# Out:
# adding new database ...

# %%
class employee:
    name = "mohit"
    def __init__(self):
        print(self)
s2 = employee()

# %%
print(s2)

# %%
 # parameter
class student:
    def __init__(self,fullname):
        self.name = fullname
s1 = student("dinesh")
print(s1.name)
# Out:
# dinesh

# %%
s2 =student("ram das")
print(s2.name)
# Out:
# ram das

# %%
class student:
    def __init__(self,name):
        self.name = name
s1 = student("sneha")
print(s1.name)
# Out:
# sneha

# %%
class student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
s1 = student("sneha",98)
print(s1.name,s1.marks)
# Out:
# sneha 98

# %%
s1 = student("simi",97)
s1.name,s1.marks
# Out:
# ('simi', 97)

# %% [raw]
#  default constructor -->
#  def _init__(self)
#
#  parameterized constructures-->
#  def __init__(self,name,marks)
#  def __init__(self,name):

# %% [markdown]
# # Attributes in python oops

# %%
# object attribute higher piroty
class student:
    collage_name = "ssvm school"  #class attribute
    def __init__(self,name,marks):
        self.name = name
        self.marks= marks
s1 = student("suhasini",99)   #object attribute
print(student.collage_name)
print(s1.marks,s1.name)
# Out:
# ssvm school
# 99 suhasini

# %% [markdown]
# # Methodes in python oops

# %%
class student:
    def __init__(self,fullname):
        self.fullname= fullname
    def welcome(self):
        print("Welcom to our startup enevrment")
        print("thanks to join", self.fullname)
s1 = student("subhasish")
s1.welcome()
# Out:
# Welcom to our startup enevrment
# thanks to join subhasish

# %% [markdown]
# # Q. create student class that takes name and mark of 3 subjects as arguments in constructure.then create a menthod to print the average.

# %%
class student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
    def get_avarage(self):
        sum = 0
        for val in self.marks:
            sum +=val
        print("hi",self.name,"your avarage marks is :",sum/3)
s1 = student("tony stark", [99,87,69])
s1.get_avarage()
# Out:
# hi tony stark your avarage marks is : 85.0

# %%
s1.name= "ironman"
s1.get_avarage()
# Out:
# hi ironman your avarage marks is : 85.0

# %% [markdown]
# # Static method

# %%
# static method -> that don'tuse self parameter
class student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
    @staticmethod
    def hello():
        print("hello")
s1 = student("rohit sharama",99)
s1.hello()
# Out:
# hello

# %% [markdown]
# # 4- PILLERS OF OOPS

# %% [raw]
# 1. ABSTRACTION
# 2. ENCAPUSULATION
# 3. INHERITANCE
# 4. POLYMORPHI

# %% [markdown]
# # abstraction

# %% [raw]
# hiding rthe implementation details of a class and only showing the essintial details to user

# %%
class Car:
    def __init__(self):
        self.acc = False
        self.brek = False
        self.cluth = False
    def start(self):
        self.cluth = True
        self.acc = True
        print("car started...")
car1 = Car()
car1.start()
# Out:
# car started...

# %% [markdown]
# # Q. create account class with 2 attributes - blance and account no. create methode for debit, credit and printing the nalance

# %%
class Account:
    def __init__(self,bal,acc):
        self.balance = bal
        self.account_no = acc
    # debit methode
    def debit(self, amount):
        self.balance -= amount
        print("RS",amount,"was debited")
        print("total balance=", self.get_balance())
    # credit method
    def credit(self, amount):
        self.balance += amount
        print("RS",amount,"was credited")
        print("total balance=", self.get_balance())
    # return final value
    def get_balance(self):
        return self.balance

acc1 = Account(10000,1245)
print(acc1.balance)
print(acc1.account_no)
acc1.debit(1000)
acc1.credit(500)
acc1.credit(1200)
# Out:
# 10000
# 1245
# RS 1000 was debited
# total balance= 9000
# RS 500 was credited
# total balance= 9500
# RS 1200 was credited
# total balance= 10700

# %% [markdown]
# # del Methodes

# %%
class student:
    def __init__(self,name):
        self.name = name 
s1 = student("simi")
print(s1.name)
print(s1)
del s1
# delete sl means no class 

# del s1.name
# del s1.name  delete
# print(s1) //gives error
# Out:
# simi
# ...

# %% [markdown]
# # Private attributes and methods

# %%
class Account:
    def __init__(self, acc_no, acc_pass):
        self.acc_no = acc_no
        self.__acc_pass = acc_pass
    def reset_pass(self):
        print(self.__acc_pass)

acc1  = Account("12345", "abrrace")
print(acc1.acc_no)
# print(acc1.__acc_pass)
print(acc1.reset_pass())
# Out:
# 12345
# abrrace
# None

# %%
acc1.reset_pass()
# Out:
# abrrace

# %%
print(acc1.reset_pass())
# Out:
# abrrace
# None

# %%
class person:
    __name = "subhasish"
    def __hello(self):
        print("hello person")
    def welcome(self):
        self.__hello()
p1 = person()
# print(p1.__name)
print(p1.welcome())
# Out:
# hello person
# None

# %% [markdown]
# # INHERITANCE

# %% [raw]
# when one class derive the properties % methodes of another class

# %%
class Car:
    color = "black"
    @staticmethod
    def start():
        print("car start...")
        
    @staticmethod 
    def stop():
        print("car stope ...")
class ToyotaCar(Car):
    def __init__(self,name):
        self.name = name
car1 = ToyotaCar("fortuner")
car2 = ToyotaCar("prius")
print(car1.name)
print(car1.start())
# Out:
# fortuner
# car start...
# None

# %%
print(Car.start())
# Out:
# car start...
# None

# %%
print(Car.stop())
# Out:
# car stope ...
# None

# %%
print(Car.color)
# Out:
# black

# %% [markdown]
# # Types of inheritance

# %% [raw]
# 1. single inheritance   A-> B
# 2. multi-level inheritance   a-> b-> c
# 3. multiple inheritance       a->  b and c

# %% [markdown]
# # multi-level inheritance

# %%
class Car:
    @staticmethod
    def start():
        print("car start...")
        
    @staticmethod 
    def stop():
        print("car stope ...")

class ToyotaCar(Car):
    def __init__(self,brand):
        self.brand = brand

class Fortuner(ToyotaCar):
    def __init__(self,type):
        self.type = type
car1 = Fortuner("disel")
car1.start()
car1.stop()
# Out:
# car start...
# car stope ...

# %% [markdown]
# # multiple inheritance

# %%
# acces a,b,c all classes acces
class A:
    vara = "welcome to class a"
class B:
    varb = "welcome to class b"
class C(A,B):
    varc = "welcome to class c"
c1 = C()
print(c1.vara)
print(c1.varb)
print(c1.varc)
# Out:
# welcome to class a
# welcome to class b
# welcome to class c

# %% [markdown]
# # super methode

# %%
class car:
    def __init__(self,type):
        self.type = type
    @staticmethod
    def start():
        print("car is running..")
    @staticmethod
    def stop():
        print("car stoped..")
class Toyota(car):
    def __init__(self,name,type):
        self.name = name
        super().__init__(type)
        super().start()
car1 = Toyota("prius","electric")
print(car1.type)
# Out:
# car is running..
# electric

# %% [markdown]
# # Class methode  -@classmethod

# %% [raw]
# a class methode is bound to the class and recives the class as an implicity first argument
# static method can't acces ormodify class state & generally for utility

# %%
class person:
    name = "mohit"
    def changename(self,name):
       self.name = name
p1 = person()
p1.changename("subhasish")
print(p1.name)
print(person.name)
# Out:
# subhasish
# mohit

# %%
# 1.method -1
class person:
    name = "mohit"
    def changename(self,name):
       person.name = name
p1 = person()
p1.changename("subhasish")
print(p1.name)
print(person.name)
# Out:
# subhasish
# subhasish

# %%
# it directly hange main class 
class person:
    name = "mohit"
    @classmethod
    def changename(cls,name):
        cls.name = name 
p1 = person()
p1.changename("subhasish")
print(p1.name)
print(person.name)
# Out:
# subhasish
# subhasish

# %% [raw]
# method ->
# static methode                   ->instace and class no use
# class methode                    ->class
# instance methode/normalmethode   ->self

# %% [markdown]
# # propefrty decorator -> @property

# %%
class student:
    def __init__(self,phy,chem,math):
        self.phy= phy
        self.chem = chem
        self.math = math

        # percentage
        self.percentage = str((self.phy +self.chem +self.math)/3) + "%"
stu1 = student(98,97,99)
print(stu1.percentage)
# Out:
# 98.0%

# %%
# rechack 98 wrong 96 so how i can cjange ?
